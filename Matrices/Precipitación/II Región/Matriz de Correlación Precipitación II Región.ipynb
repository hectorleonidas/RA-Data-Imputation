# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

archivo_csv = "MatrizPPII.csv"
datos = pd.read_csv(archivo_csv)

print(datos)
# Out:
#          ID_CIDERH REGION   FECHA_RBE  PP_RBE      LAT_Y      LON_X
# 0       M_001_A_II     II  1994-06-01     0.0 -22.083189 -70.191778
# 1       M_001_A_II     II  1994-06-02     0.0 -22.083189 -70.191778
# 2       M_001_A_II     II  1994-06-03     0.0 -22.083189 -70.191778
# 3       M_001_A_II     II  1994-06-04     0.0 -22.083189 -70.191778
# 4       M_001_A_II     II  1994-06-05     0.0 -22.083189 -70.191778
# ...            ...    ...         ...     ...        ...        ...
# 326345    M_226_AA     II  1985-11-19     0.0 -23.433000 -70.467000
# 326346    M_226_AA     II  1985-12-01   400.0 -23.433000 -70.467000
# 326347    M_226_AA     II  1986-03-03     0.0 -23.433000 -70.467000
# 326348    M_226_AA     II  1986-08-19     0.0 -23.433000 -70.467000
# 326349    M_226_AA     II  1986-08-31     0.0 -23.433000 -70.467000
#
# [326350 rows x 6 columns]

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_040_A_II', 'M_039_A_II', 'M_038_A_II', 'M_041_A_II']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='PP_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Precipitación II Región')
plt.show()
# Out:
# ID_CIDERH   M_038_A_II  M_039_A_II  M_040_A_II  M_041_A_II
# ID_CIDERH
# M_038_A_II    1.000000    0.624672    0.562844    0.513173
# M_039_A_II    0.624672    1.000000    0.564796    0.509970
# M_040_A_II    0.562844    0.564796    1.000000    0.467584
# M_041_A_II    0.513173    0.509970    0.467584    1.000000

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_028_A_II', 'M_027_A_II', 'M_026_A_II', 'M_023_A_II']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='PP_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Precipitación II Región')
plt.show()
# Out:
# ID_CIDERH   M_023_A_II  M_026_A_II  M_027_A_II  M_028_A_II
# ID_CIDERH
# M_023_A_II    1.000000    0.715335    0.652278    0.583682
# M_026_A_II    0.715335    1.000000    0.671056    0.562625
# M_027_A_II    0.652278    0.671056    1.000000    0.535391
# M_028_A_II    0.583682    0.562625    0.535391    1.000000
