# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

archivo_csv = "MatrizPPI.csv"
datos = pd.read_csv(archivo_csv)

print(datos)
# Out:
#        ID_CIDERH REGION   FECHA_RBE  PP_RBE      LAT_Y      LON_X
# 0       FM_001_A      I  2006-08-01     0.0 -19.117415 -69.242992
# 1       FM_001_A      I  2006-08-02     0.0 -19.117415 -69.242992
# 2       FM_001_A      I  2006-08-03     0.0 -19.117415 -69.242992
# 3       FM_001_A      I  2006-08-04     0.0 -19.117415 -69.242992
# 4       FM_001_A      I  2006-08-05     0.0 -19.117415 -69.242992
# ...          ...    ...         ...     ...        ...        ...
# 192316   M_005_A      I  1988-06-18     0.0 -19.850881 -68.859900
# 192317   M_005_A      I  1988-06-19     0.0 -19.850881 -68.859900
# 192318   M_005_A      I  1988-06-20     0.0 -19.850881 -68.859900
# 192319   M_005_A      I  1988-06-21     0.0 -19.850881 -68.859900
# 192320   M_005_A      I  1988-06-22     0.0 -19.850881 -68.859900
#
# [192321 rows x 6 columns]

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_005_A', 'M_006_A', 'M_016_A', 'M_012_A']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='PP_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Precipitación I Región')
plt.show()
# Out:
# ID_CIDERH   M_005_A   M_006_A   M_012_A   M_016_A
# ID_CIDERH
# M_005_A    1.000000  0.719321  0.436628  0.542963
# M_006_A    0.719321  1.000000  0.618617  0.569513
# M_012_A    0.436628  0.618617  1.000000  0.485831
# M_016_A    0.542963  0.569513  0.485831  1.000000

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_025_A', 'M_023_A', 'FM_002_A', 'M_024_A']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='PP_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Precipitación I Región')
plt.show()
# Out:
# ID_CIDERH  FM_002_A   M_023_A   M_024_A   M_025_A
# ID_CIDERH
# FM_002_A   1.000000  0.553332  0.561989  0.661742
# M_023_A    0.553332  1.000000  0.463538  0.540584
# M_024_A    0.561989  0.463538  1.000000  0.558719
# M_025_A    0.661742  0.540584  0.558719  1.000000

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_025_A', 'M_023_A', 'FM_002_A', 'M_014_A']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='PP_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Precipitación I Región')
plt.show()
# Out:
# ID_CIDERH  FM_002_A   M_014_A   M_023_A   M_025_A
# ID_CIDERH
# FM_002_A   1.000000  0.799589  0.553332  0.661742
# M_014_A    0.799589  1.000000  0.380538  0.530547
# M_023_A    0.553332  0.380538  1.000000  0.540584
# M_025_A    0.661742  0.530547  0.540584  1.000000
