# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

archivo_csv = "MatrizTMI.csv"
datos = pd.read_csv(archivo_csv)

print(datos)
# Out:
#       ID_CIDERH REGION   FECHA_RBE  TEMP_MEDIA_RBE      LAT_Y      LON_X
# 0      M_001_AH      I  2004-11-01        8.310000 -20.678125 -68.707308
# 1      M_001_AH      I  2004-11-02        7.170000 -20.678125 -68.707308
# 2      M_001_AH      I  2004-11-03        6.894000 -20.678125 -68.707308
# 3      M_001_AH      I  2004-11-04        7.800000 -20.678125 -68.707308
# 4      M_001_AH      I  2004-11-05        8.010000 -20.678125 -68.707308
# ...         ...    ...         ...             ...        ...        ...
# 62100  M_005_AH      I  2011-12-27       10.179167 -20.325063 -68.894615
# 62101  M_005_AH      I  2011-12-28        8.987500 -20.325063 -68.894615
# 62102  M_005_AH      I  2011-12-29        9.275000 -20.325063 -68.894615
# 62103  M_005_AH      I  2011-12-30        8.483333 -20.325063 -68.894615
# 62104  M_005_AH      I  2011-12-31        8.687500 -20.325063 -68.894615
#
# [62105 rows x 6 columns]

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_005_AH', 'M_003_AH', 'M_016_A', 'M_002_AJ']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='TEMP_MEDIA_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Temp Media I Región')
plt.show()

# Contar la cantidad de datos de TEMP_MEDIA_RBE para cada estación seleccionada
cantidad_datos_temp_min_por_estacion = datos_especificos.groupby('ID_CIDERH')['TEMP_MEDIA_RBE'].count()

# Mostrar la cantidad de datos para cada estación
print("Cantidad de datos de TEMP_MEDIA_RBE por estación:")
print(cantidad_datos_temp_min_por_estacion)
# Out:
# ID_CIDERH  M_002_AJ  M_003_AH  M_005_AH   M_016_A
# ID_CIDERH
# M_002_AJ   1.000000  0.760143  0.935162  0.921042
# M_003_AH   0.760143  1.000000  0.778635  0.761385
# M_005_AH   0.935162  0.778635  1.000000  0.939457
# M_016_A    0.921042  0.761385  0.939457  1.000000
# Cantidad de datos de TEMP_MEDIA_RBE por estación:
# ID_CIDERH
# M_002_AJ    1125
# M_003_AH     356
# M_005_AH     188
# M_016_A     8621
# Name: TEMP_MEDIA_RBE, dtype: int64

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_005_Q', 'M_002_Q', 'M_006_Q', 'M_019_A']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='TEMP_MEDIA_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Temp Media I Región')
plt.show()

# Contar la cantidad de datos de TEMP_MEDIA_RBE para cada estación seleccionada
cantidad_datos_temp_min_por_estacion = datos_especificos.groupby('ID_CIDERH')['TEMP_MEDIA_RBE'].count()

# Mostrar la cantidad de datos para cada estación
print("Cantidad de datos de TEMP_MEDIA_RBE por estación:")
print(cantidad_datos_temp_min_por_estacion)
# Out:
# ID_CIDERH   M_002_Q   M_005_Q   M_006_Q   M_019_A
# ID_CIDERH
# M_002_Q    1.000000  0.855509  0.900501  0.846183
# M_005_Q    0.855509  1.000000  0.864280  0.738587
# M_006_Q    0.900501  0.864280  1.000000  0.806013
# M_019_A    0.846183  0.738587  0.806013  1.000000
# Cantidad de datos de TEMP_MEDIA_RBE por estación:
# ID_CIDERH
# M_002_Q    1675
# M_005_Q     334
# M_006_Q      92
# M_019_A    5276
# Name: TEMP_MEDIA_RBE, dtype: int64

# %%
# Lista de estaciones específicas
estaciones_especificas = ['M_008_H', 'M_004_H', 'M_002_AH', 'M_007_H']

# Filtra los datos para las estaciones específicas
datos_especificos = datos[datos['ID_CIDERH'].isin(estaciones_especificas)]

# Pivotar los datos para obtener una matriz de temperaturas mínimas por fecha y estación
matriz_temp_min = datos_especificos.pivot(index='FECHA_RBE', columns='ID_CIDERH', values='TEMP_MEDIA_RBE')

# Calcular la matriz de correlaciones de Spearman
matriz_correlaciones = matriz_temp_min.corr(method='spearman')

# Mostrar la matriz de correlaciones
print(matriz_correlaciones)

# Visualizar la matriz de correlaciones con un mapa de calor usando seaborn
sns.heatmap(matriz_correlaciones, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlaciones de Spearman Temp Media I Región')
plt.show()

# Contar la cantidad de datos de TEMP_MEDIA_RBE para cada estación seleccionada
cantidad_datos_temp_min_por_estacion = datos_especificos.groupby('ID_CIDERH')['TEMP_MEDIA_RBE'].count()

# Mostrar la cantidad de datos para cada estación
print("Cantidad de datos de TEMP_MEDIA_RBE por estación:")
print(cantidad_datos_temp_min_por_estacion)
# Out:
# ID_CIDERH  M_002_AH  M_004_H
# ID_CIDERH
# M_002_AH        1.0      NaN
# M_004_H         NaN      1.0
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# Cantidad de datos de TEMP_MEDIA_RBE por estación:
# ID_CIDERH
# M_002_AH     603
# M_004_H     1276
# Name: TEMP_MEDIA_RBE, dtype: int64
